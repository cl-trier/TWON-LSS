# %%
import networkx
import matplotlib.pyplot as plt

from twon_lss import Graph

# %%
my_graph = Graph.from_random_regular(5, 100)
print(my_graph)
# Out:
# Graph with 100 nodes and 250 edges

# %%
plt.figure(figsize=(12, 12), dpi=300)

networkx.draw_networkx(my_graph.structure, with_labels=True, width=0.5, font_size=6)
