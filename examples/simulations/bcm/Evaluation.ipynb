# %%
import json

import pandas
import seaborn

# %%
seaborn.set_style()

# %%
data = pandas.concat([
    pandas.Series(data["memory"], name=idx)
    for idx, data in json.load(open("output/individuals.step_50.json")).items()
], axis=1)
data
# Out:
#      user-c46e7212-df4e-42a6-a5a1-243bb2e56a53  \
# 0                                     0.202682
# 1                                     0.202682
# 2                                     0.202682
# 3                                     0.202682
# 4                                     0.202682
# ..                                         ...
# 96                                    0.187588
# 97                                    0.171003
# 98                                    0.167944
# 99                                    0.154480
# 100                                   0.159456
#
#      user-f7474839-a42c-4fe5-8ffc-1c173d35792e  \
# 0                                     0.189984
# 1                                     0.166744
# 2                                     0.182694
# 3                                     0.263743
# 4                                     0.233127
# ..                                         ...
# 96                                    0.695176
# 97                                    0.692174
# 98                                    0.722275
# 99                                    0.685617
# 100                                   0.685617
#
#      user-27cb7113-78b8-4154-abbb-3f2abb7ae088  \
# 0                                     0.337780
# 1                                     0.337780
# 2                                     0.353183
# 3                                     0.353183
# 4                                     0.367045
# ..                                         ...
# 96                                    0.371473
# 97                                    0.349766
# 98                                    0.349766
# 99                                    0.368434
# 100                                   0.361946
#
#      user-676c8a97-86b2-4a5e-a429-10f02c8263f5  \
# 0                                     0.841835
# 1                                     0.841835
# 2                                     0.841835
# 3                                     0.841835
# 4                                     0.841835
# ..                                         ...
# 96                                    0.509851
# 97                                    0.497272
# 98                                    0.490649
# 99                                    0.492865
# 100                                   0.484800
#
#      user-79939eb9-bd3f-40a6-b0de-f2af8add539c  \
# 0                                    -0.658592
# 1                                    -0.596975
# 2                                    -0.538672
# 3                                    -0.476127
# 4                                    -0.432756
# ..                                         ...
# 96                                    0.283571
# 97                                    0.256671
# 98                                    0.256671
# 99                                    0.274470
# 100                                   0.292451
#
#      user-cb3c54ec-a639-43d2-8188-d55d5872f713  \
# 0                                    -0.823357
# 1                                    -0.674830
# 2                                    -0.519799
# 3                                    -0.477499
# 4                                    -0.465825
# ..                                         ...
# 96                                    0.346298
# 97                                    0.316009
# 98                                    0.286203
# 99                                    0.345131
# 100                                   0.337797
#
#      user-941eab60-9a1b-4fcd-8a7c-b09258548b1b  \
# 0                                    -0.599603
# 1                                    -0.473451
# 2                                    -0.326788
# 3                                    -0.194791
# 4                                    -0.124725
# ..                                         ...
# 96                                    0.652204
# 97                                    0.686302
# 98                                    0.686302
# 99                                    0.653241
# 100                                   0.638185
#
#      user-10b0aaea-b2b3-44e8-be39-45b089482bca  \
# 0                                     0.655731
# 1                                     0.655731
# 2                                     0.655731
# 3                                     0.655419
# 4                                     0.655419
# ..                                         ...
# 96                                    0.449199
# 97                                    0.445523
# 98                                    0.437957
# 99                                    0.436126
# 100                                   0.451406
#
#      user-a0c82e9c-e175-4a18-b09b-ffd18a50568c  \
# 0                                     0.584138
# 1                                     0.584138
# 2                                     0.602163
# 3                                     0.573499
# 4                                     0.571534
# ..                                         ...
# 96                                    0.377110
# 97                                    0.382503
# 98                                    0.374943
# 99                                    0.345612
# 100                                   0.357004
#
#      user-4bc02c78-10ef-4148-80b6-9c6e711a72ee  ...  \
# 0                                    -0.689290  ...
# 1                                    -0.665395  ...
# 2                                    -0.687034  ...
# 3                                    -0.612279  ...
# 4                                    -0.587126  ...
# ..                                         ...  ...
# 96                                    0.219275  ...
# 97                                    0.227517  ...
# 98                                    0.204561  ...
# 99                                    0.200292  ...
# 100                                   0.173097  ...
#
#      user-3f2c0311-1b16-4af4-8a53-d9abe96adb67  \
# 0                                    -0.042873
# 1                                     0.038634
# 2                                     0.100343
# 3                                     0.167528
# 4                                     0.216349
# ..                                         ...
# 96                                    0.264981
# 97                                    0.275278
# 98                                    0.251809
# 99                                    0.256297
# 100                                   0.292596
#
#      user-ddfc5318-abbe-4f22-b3a3-f7e4020c0f14  \
# 0                                    -0.992756
# 1                                    -0.931437
# 2                                    -0.909577
# 3                                    -0.907704
# 4                                    -0.854890
# ..                                         ...
# 96                                    0.409069
# 97                                    0.401027
# 98                                    0.398298
# 99                                    0.391362
# 100                                   0.357301
#
#      user-0628d466-f38a-42b6-af7c-6f711ad04595  \
# 0                                    -0.093779
# 1                                    -0.122358
# 2                                    -0.060941
# 3                                    -0.005666
# 4                                    -0.014780
# ..                                         ...
# 96                                    0.396686
# 97                                    0.409954
# 98                                    0.411438
# 99                                    0.374376
# 100                                   0.357937
#
#      user-85f8f33b-5048-497b-a1c5-88299fabe25e  \
# 0                                    -0.942259
# 1                                    -0.870736
# 2                                    -0.734481
# 3                                    -0.611853
# 4                                    -0.641670
# ..                                         ...
# 96                                    0.424728
# 97                                    0.439260
# 98                                    0.443129
# 99                                    0.465830
# 100                                   0.478254
#
#      user-d8a283c7-e1f7-426f-9954-f5f39f3d653b  \
# 0                                    -0.013943
# 1                                     0.086770
# 2                                     0.067808
# 3                                     0.160346
# 4                                     0.134631
# ..                                         ...
# 96                                    0.681284
# 97                                    0.656480
# 98                                    0.625848
# 99                                    0.594704
# 100                                   0.594704
#
#      user-79727831-5bf9-414e-8ad8-dbe1811a9911  \
# 0                                     0.658593
# 1                                     0.620473
# 2                                     0.620473
# 3                                     0.589978
# 4                                     0.589978
# ..                                         ...
# 96                                    0.339935
# 97                                    0.310551
# 98                                    0.312499
# 99                                    0.334603
# 100                                   0.336836
#
#      user-ff66e9f8-2bb6-40c0-892a-15470ced778e  \
# 0                                    -0.867194
# 1                                    -0.714616
# 2                                    -0.704867
# 3                                    -0.599062
# 4                                    -0.592420
# ..                                         ...
# 96                                    0.243695
# 97                                    0.249755
# 98                                    0.258906
# 99                                    0.231173
# 100                                   0.240382
#
#      user-98b9dceb-d966-49dc-9924-0b291a279e0c  \
# 0                                    -0.053752
# 1                                    -0.084452
# 2                                    -0.084452
# 3                                    -0.084452
# 4                                    -0.084452
# ..                                         ...
# 96                                    0.189710
# 97                                    0.207302
# 98                                    0.181131
# 99                                    0.191101
# 100                                   0.192182
#
#      user-12755950-1cc5-4377-8bad-28f6d527c556  \
# 0                                     0.392230
# 1                                     0.392230
# 2                                     0.429447
# 3                                     0.483340
# 4                                     0.483340
# ..                                         ...
# 96                                    0.482027
# 97                                    0.465704
# 98                                    0.450104
# 99                                    0.504499
# 100                                   0.519020
#
#      user-baadef41-e46a-4c0a-bdfc-588b26ce1e90
# 0                                    -0.860952
# 1                                    -0.687309
# 2                                    -0.614266
# 3                                    -0.546184
# 4                                    -0.407382
# ..                                         ...
# 96                                    0.513117
# 97                                    0.509959
# 98                                    0.503737
# 99                                    0.502555
# 100                                   0.478742
#
# [101 rows x 100 columns]

# %%
(
    seaborn.lineplot(
        df := (
            data
            .reset_index()
            .melt(id_vars=["index"])
            .rename(columns={"index": "step"})
        ), 
        **(axis := dict(
            x="step", 
            y="value"
        )), 
        hue="variable",
        lw=0.5,
        legend=False,
    ),
    seaborn.lineplot(
        df, 
        **axis,
        lw=2.0,
        legend=False,
        err_kws={'linestyle': '--', 'hatch': 'xxx', 'alpha': 0.4}
    )
)
# Out:
# (<Axes: xlabel='step', ylabel='value'>, <Axes: xlabel='step', ylabel='value'>)
