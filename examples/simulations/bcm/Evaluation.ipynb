# %%
import json

import pandas
import seaborn

# %%
seaborn.set_style()

# %%
data = pandas.concat([
    pandas.Series(data["memory"], name=idx)
    for idx, data in json.load(open("output/individuals.step_499.json")).items()
], axis=1)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 data = pandas.concat([
#       2     pandas.Series(data["memory"], name=idx)
# ----> 3     for idx, data in json.load(open("output/individuals.step_499.json")).items()
#       4 ], axis=1)
#       5 data
#
# File ~/Repositories/TWON-Collection/TWON-LSS/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/individuals.step_499.json'

# %%
(
    seaborn.lineplot(
        df := (
            data
            .reset_index()
            .melt(id_vars=["index"])
            .rename(columns={"index": "step"})
        ), 
        **(axis := dict(
            x="step", 
            y="value"
        )), 
        hue="variable",
        lw=0.5,
        legend=False,
    ),
    seaborn.lineplot(
        df, 
        **axis,
        lw=2.0,
        legend=False,
        err_kws={'linestyle': '--', 'hatch': 'xxx', 'alpha': 0.4}
    )
)
# Out:
# (<Axes: xlabel='step', ylabel='value'>, <Axes: xlabel='step', ylabel='value'>)
