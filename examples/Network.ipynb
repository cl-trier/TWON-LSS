# %%
import networkx
import matplotlib.pyplot as plt

from twon_lss.schemas import Network

# %%
network = Network.from_graph(networkx.random_regular_graph(5, 50))
print(network)
# Out:
# Graph with 0 nodes and 0 edges

# %%
plt.figure(figsize=(12, 12), dpi=300)

networkx.draw_networkx(network.graph, with_labels=True, width=0.5, font_size=6)
